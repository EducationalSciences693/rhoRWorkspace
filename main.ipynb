# %% [markdown]
# # Imports

# %%
library(rhoR)
# Out:
# Attaching package: ‘rhoR’
#
#
# The following object is masked from ‘package:base’:
#
#     kappa

# %% [markdown]
# # Load Data

# %%
data = read.csv("sample-coded.csv")
firstRater = data$Machine
secondRater = data$Mariah
codeSet = cbind(firstRater, secondRater)
ts = getTestSet(codeSet, 80, testSetBaserateInflation=0.20)

# %% [markdown]
# # Compute rho

# %%
rho(ts)
# Out:
# $rho
# [1] 1
#
# $kappa
# [1] 0.4827586
#
# $recall
# [1] 0.5
#
# $precision
# [1] 0.6666667
