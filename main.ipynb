# %% [markdown]
# # Imports

# %%
installed.packages()
# Out:
#            Package    LibPath            Version Priority
# base64enc  base64enc  /srv/rlibs         0.1-3   NA
# cli        cli        /srv/rlibs         3.1.0   NA
# crayon     crayon     /srv/rlibs         1.4.2   NA
# curl       curl       /srv/rlibs         3.1     NA
# devtools   devtools   /srv/rlibs         1.13.4  NA
# digest     digest     /srv/rlibs         0.6.28  NA
# ellipsis   ellipsis   /srv/rlibs         0.3.2   NA
# evaluate   evaluate   /srv/rlibs         0.14    NA
# fansi      fansi      /srv/rlibs         0.5.0   NA
# fastmap    fastmap    /srv/rlibs         1.1.0   NA
# git2r      git2r      /srv/rlibs         0.21.0  NA
# glue       glue       /srv/rlibs         1.5.0   NA
# htmltools  htmltools  /srv/rlibs         0.5.2   NA
# httr       httr       /srv/rlibs         1.3.1   NA
# IRdisplay  IRdisplay  /srv/rlibs         1.0     NA
# IRkernel   IRkernel   /srv/rlibs         1.1     NA
# jsonlite   jsonlite   /srv/rlibs         1.7.2   NA
# ...

# %%
library(rhoR)
# Out:
# Error in library(rhoR): there is no package called ‘rhoR’
# Traceback:
#
# 1. library(rhoR)

# %%
firstRater = c(1, 1, 1, 1)
secondRater = c(1, 1, 0, 1)
codeSet = cbind(firstRater, secondRater)
ts = getTestSet(codeSet, 80, testSetBaserateInflation=0.20)
rho(ts)
